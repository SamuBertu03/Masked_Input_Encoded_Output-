# %% [markdown]
# # Dataset Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

def analizza_dataset(path):
    """
    Analizza un dataset CSV e classifica ogni feature per tipo
    """
    # Carico il dataset
    df = pd.read_csv(path)
    
    print("="*60)
    print("ANALISI DATASET - CLASSIFICAZIONE FEATURE")
    print("="*60)
    
    print(f"\nDimensioni dataset: {df.shape[0]} righe, {df.shape[1]} colonne")
    
    # Dizionario per classificare le feature
    classificazione = {
        'BINARIE': [],
        'CATEGORICHE_BASSA_CARDINALITA': [],
        'CATEGORICHE_ALTA_CARDINALITA': [],
        'NUMERICHE_DISCRETE': [],
        'NUMERICHE_CONTINUE': [],
        'DATE/DATETIME': [],
        'TESTO_LUNGO': [],
        'ALTRO': []
    }
    
    # Analisi dettagliata per ogni colonna
    for col in df.columns:
        serie = df[col].dropna()  # Rimuovo valori nulli per l'analisi
        
        if len(serie) == 0:  # Colonna completamente vuota
            classificazione['ALTRO'].append((col, "VUOTA", 0, []))
            continue
            
        n_unique = serie.nunique()
        tipo_pandas = str(serie.dtype)
        esempi = list(serie.unique()[:5]) if n_unique <= 20 else list(serie.unique()[:3])           # Lista rappresentativa di valori della colonna
        
        # Classifico la feature
        if n_unique == 2:
            # Binaria
            classificazione['BINARIE'].append((col, tipo_pandas, n_unique, esempi))
            
        elif n_unique == 1:
            # Costante
            classificazione['ALTRO'].append((col, "COSTANTE", n_unique, esempi))
            
        elif 'datetime' in tipo_pandas.lower() or col.lower() in ['date', 'time', 'datetime']:
            # Data/Datetime
            classificazione['DATE/DATETIME'].append((col, tipo_pandas, n_unique, esempi))
            
        elif tipo_pandas == 'object':
            # Verifico se contiene stringhe lunghe (testo)
            lunghezza_media = serie.astype(str).str.len().mean() if len(serie) > 0 else 0
            
            if lunghezza_media > 50:  # Testo lungo
                classificazione['TESTO_LUNGO'].append((col, tipo_pandas, n_unique, esempi))
            elif n_unique <= 20:  # Soglia per categoriche a bassa cardinalità
                classificazione['CATEGORICHE_BASSA_CARDINALITA'].append((col, tipo_pandas, n_unique, esempi))
            else:
                classificazione['CATEGORICHE_ALTA_CARDINALITA'].append((col, tipo_pandas, n_unique, esempi))
                
        elif tipo_pandas in ['int64', 'int32', 'float64', 'float32']:
            # Numeriche
            if n_unique <= 20 and serie.dtype == 'int64':
                # Probabilmente discreta
                classificazione['NUMERICHE_DISCRETE'].append((col, tipo_pandas, n_unique, esempi))
            else:
                # Continua
                classificazione['NUMERICHE_CONTINUE'].append((col, tipo_pandas, n_unique, esempi))
        else:
            classificazione['ALTRO'].append((col, tipo_pandas, n_unique, esempi))
    
    # Stampo risultati
    for categoria, features in classificazione.items():
        if features:
            print(f"\n{categoria} ({len(features)} features):")
            print("-" * 50)
            for nome, tipo, n_val, esempi in features:
                print(f"  • {nome}")
                print(f"    Tipo: {tipo} | Valori unici: {n_val}")
                print(f"    Esempi: {esempi}")
                if nome in df.columns:
                    null_count = df[nome].isnull().sum()
                    null_perc = (null_count / len(df)) * 100
                    print(f"    Valori nulli: {null_count} ({null_perc:.1f}%)")
                print()
    
    # Sommario
    print("\n" + "="*60)
    print("SOMMARIO CLASSIFICAZIONE")
    print("="*60)
    totale = sum(len(features) for features in classificazione.values())
    for categoria, features in classificazione.items():
        if features:
            percentuale = (len(features) / totale) * 100
            print(f"{categoria:.<35} {len(features):>3} ({percentuale:5.1f}%)")
    
    return df, classificazione

def analisi_correlazioni_binarie(df, classificazione):
    """
    Analizza le correlazioni tra variabili binarie
    """
    binarie = [nome for nome, _, _, _ in classificazione['BINARIE']]
    
    if len(binarie) > 1:
        print(f"\n\nCORRELAZIONI TRA VARIABILI BINARIE ({len(binarie)} variabili):")
        print("-" * 60)
        
        df_bin = df[binarie]
        corr_matrix = df_bin.corr()
        
        # Trovo correlazioni forti (> 0.7 o < -0.7)
        correlazioni_forti = []
        for i in range(len(corr_matrix.columns)):
            for j in range(i+1, len(corr_matrix.columns)):
                corr = corr_matrix.iloc[i, j]
                if abs(corr) > 0.7:
                    correlazioni_forti.append((corr_matrix.columns[i], 
                                             corr_matrix.columns[j], corr))
        
        if correlazioni_forti:
            print("Correlazioni forti (|r| > 0.7):")
            for var1, var2, corr in correlazioni_forti:
                print(f"  {var1} <-> {var2}: {corr:.3f}")
        else:
            print("Nessuna correlazione forte trovata tra variabili binarie.")

def analisi_numeriche(df, classificazione):
    """
    Analisi delle variabili numeriche
    """
    numeriche = ([nome for nome, _, _, _ in classificazione['NUMERICHE_CONTINUE']] + 
                [nome for nome, _, _, _ in classificazione['NUMERICHE_DISCRETE']])
    
    if numeriche:
        print(f"\n\nSTATISTICHE VARIABILI NUMERICHE ({len(numeriche)} variabili):")
        print("-" * 60)
        
        stats = df[numeriche].describe()
        print(stats.round(2))

# Esecuzione dell'analisi
if __name__ == "__main__":
    
    file_path = "../updated_data___censored.csv"  
    
    try:
        df, classificazione = analizza_dataset(file_path)
        analisi_correlazioni_binarie(df, classificazione)
        analisi_numeriche(df, classificazione)
        
    except FileNotFoundError:
        print(f"File {file_path} non trovato. Assicurati che il path sia corretto.")
    except Exception as e:
        print(f"Errore durante l'analisi: {e}")

# FUNZIONI AGGIUNTIVE PER ANALISI SPECIFICA

def controlla_pattern_genetici(df):
    """
    Identifica pattern specifici per dati genetici (rs...)
    """
    colonne_genetiche = [col for col in df.columns if col.startswith('rs')]
    if colonne_genetiche:
        print(f"\n\nVARIABILI GENETICHE IDENTIFICATE ({len(colonne_genetiche)}):")
        print("-" * 50)
        for col in colonne_genetiche[:10]:  # Mostra primi 10
            valori = df[col].value_counts().head()
            print(f"{col}: {dict(valori)}")

def controlla_variabili_tempo(df):
    """
    Identifica variabili legate al tempo
    """
    colonne_tempo = [col for col in df.columns if any(keyword in col.lower() 
                    for keyword in ['time', 'date', 'month', 'year', 'age', 'duration'])]
    
    if colonne_tempo:
        print(f"\n\nVARIABILI TEMPORALI IDENTIFICATE ({len(colonne_tempo)}):")
        print("-" * 50)
        for col in colonne_tempo[:10]:
            if col in df.columns:
                print(f"{col}: range {df[col].min()} - {df[col].max()}")

# Eseguo anche queste analisi specifiche
if __name__ == "__main__":
    try:
        controlla_pattern_genetici(df)
        controlla_variabili_tempo(df)
    except:
        pass
# Out:
# /tmp/ipykernel_4036518/2039534506.py:12: DtypeWarning: Columns (11,107,109,111) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# ============================================================
# ANALISI DATASET - CLASSIFICAZIONE FEATURE
# ============================================================
#
# Dimensioni dataset: 502412 righe, 306 colonne
#
# BINARIE (137 features):
# --------------------------------------------------
#   • Sex
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • PW_abnp_0
#     Tipo: float64 | Valori unici: 2
#     Esempi: [0.0, 1.0]
#     Valori nulli: 331698 (66.0%)
#
#   • Above_moderate_vigorous
#     Tipo: float64 | Valori unici: 2
#     Esempi: [1.0, 0.0]
#     Valori nulli: 100106 (19.9%)
#
#   • Above_walking_moderate_vigorous
#     Tipo: float64 | Valori unici: 2
#     Esempi: [1.0, 0.0]
#     Valori nulli: 100218 (19.9%)
#
#   • Quality_IMT_120
#     Tipo: float64 | Valori unici: 2
#     Esempi: [1.0, 2.0]
#     Valori nulli: 499834 (99.5%)
#
#   • Quality_IMT_150
#     Tipo: float64 | Valori unici: 2
#     Esempi: [1.0, 2.0]
#     Valori nulli: 499834 (99.5%)
#
#   • Quality_IMT_210
#     Tipo: float64 | Valori unici: 2
#     Esempi: [1.0, 2.0]
#     Valori nulli: 499834 (99.5%)
#
#   • Quality_IMT_240
#     Tipo: float64 | Valori unici: 2
#     Esempi: [1.0, 2.0]
#     Valori nulli: 499834 (99.5%)
#
#   • K_urine_flag_0
#     Tipo: object | Valori unici: 2
#     Esempi: ['>200', '<2.0']
#     Valori nulli: 501393 (99.8%)
#
#   • Na_urine_flag_0
#     Tipo: object | Valori unici: 2
#     Esempi: ['<10', '>400']
#     Valori nulli: 501383 (99.8%)
#
#   • Coffee_0
#     Tipo: float64 | Valori unici: 2
#     Esempi: [0.0, 1.0]
#     Valori nulli: 431721 (85.9%)
#
#   • Coffee_4
#     Tipo: float64 | Valori unici: 2
#     Esempi: [1.0, 0.0]
#     Valori nulli: 402189 (80.1%)
#
#   • Alcohol_cat_0
#     Tipo: float64 | Valori unici: 2
#     Esempi: [0.0, 1.0]
#     Valori nulli: 431721 (85.9%)
#
#   • Alcohol_cat_4
#     Tipo: float64 | Valori unici: 2
#     Esempi: [1.0, 0.0]
#     Valori nulli: 402189 (80.1%)
#
#   • Med_cbde_3_0
#     Tipo: float64 | Valori unici: 2
#     Esempi: [4.0, 5.0]
#     Valori nulli: 502319 (100.0%)
#
#   • Med_cbd_1_0
#     Tipo: float64 | Valori unici: 2
#     Esempi: [2.0, 3.0]
#     Valori nulli: 467990 (93.1%)
#
#   • label_10
#     Tipo: float64 | Valori unici: 2
#     Esempi: [1.0, 0.0]
#     Valori nulli: 40066 (8.0%)
#
#   • Ethnic__-3
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Ethnic__-1
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Ethnic__4
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Ethnic__5
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Ethnic__6
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs2820037__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs2820037__A_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs2820037__T_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs2820037__T_T
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs1805762__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs1805762__C_C
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs1805762__G_C
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs1805762__G_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs1126742__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs1126742__A_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs1126742__G_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs1126742__G_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs2398162__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs2398162__A_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs2398162__G_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs2398162__G_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs4149601__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs4149601__A_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs4149601__A_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs4149601__G_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs6749447__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs6749447__G_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs6749447__G_T
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs6749447__T_T
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs5186__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs5186__A_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs5186__C_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs5186__C_C
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs4961__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs4961__G_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs4961__T_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs4961__T_T
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs2231142__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs2231142__G_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs2231142__T_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs2231142__T_T
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs72552713__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs72552713__A_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs72552713__G_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs3114018__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs3114018__A_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs3114018__A_C
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs3114018__C_C
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs16890979__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs16890979__C_C
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs16890979__T_C
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs16890979__T_T
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs737267__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs737267__G_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs737267__T_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs737267__T_T
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs6855911__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs6855911__A_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs6855911__G_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs6855911__G_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs3775948__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs3775948__C_C
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs3775948__G_C
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs3775948__G_G
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs1165205__0_0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs1165205__A_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • rs1165205__T_A
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • rs1165205__T_T
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__None_of_the_above_(group_2)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Prefer_not_to_answer_(group_2)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Do_not_know_(group_2)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__None_of_the_above_(group_1)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Prefer_not_to_answer_(group_1)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Do_not_know_(group_1)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Heart_disease__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Stroke__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Lung_cancer__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Bowel_cancer__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Chronic_bronchitis/emphysema__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__High_blood_pressure__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Diabetes__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Alzheimer_disease/dementia__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Parkinson_disease__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Severe_depression__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_father__Prostate_cancer__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__None_of_the_above_(group_2)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Prefer_not_to_answer_(group_2)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Do_not_know_(group_2)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__None_of_the_above_(group_1)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Prefer_not_to_answer_(group_1)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Do_not_know_(group_1)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Heart_disease__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Stroke__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Lung_cancer__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Bowel_cancer__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Breast_cancer__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Chronic_bronchitis/emphysema__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__High_blood_pressure__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Diabetes__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Alzheimer_disease/dementia__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Parkinson_disease__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_mother__Severe_depression__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__None_of_the_above_(group_2)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Prefer_not_to_answer_(group_2)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Do_not_know_(group_2)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__None_of_the_above_(group_1)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [1, 0]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Prefer_not_to_answer_(group_1)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Do_not_know_(group_1)__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Heart_disease__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Stroke__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Lung_cancer__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Bowel_cancer__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Breast_cancer__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Chronic_bronchitis/emphysema__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__High_blood_pressure__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Diabetes__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Alzheimer_disease/dementia__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Parkinson_disease__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Severe_depression__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#   • Familiarity_siblings__Prostate_cancer__0
#     Tipo: int64 | Valori unici: 2
#     Esempi: [0, 1]
#     Valori nulli: 0 (0.0%)
#
#
# CATEGORICHE_ALTA_CARDINALITA (4 features):
# --------------------------------------------------
#   • Vdate_0
#     Tipo: object | Valori unici: 1068
#     Esempi: ['2009-12-03', '2009-02-26', '2007-11-06']
#     Valori nulli: 0 (0.0%)
#
#   • Lost_FU
#     Tipo: object | Valori unici: 608
#     Esempi: ['2012-08-15', '2013-06-05', '2014-03-10']
#     Valori nulli: 501114 (99.7%)
#
#   • Death_date
#     Tipo: object | Valori unici: 4649
#     Esempi: ['2017-05-15', '2020-02-19', '2018-01-24']
#     Valori nulli: 467376 (93.0%)
#
#   • Cause_of_death
#     Tipo: object | Valori unici: 1197
#     Esempi: ['I251', 'G301', 'J440']
#     Valori nulli: 467497 (93.1%)
#
#
# NUMERICHE_DISCRETE (1 features):
# --------------------------------------------------
#   • Vmonth_0
#     Tipo: int64 | Valori unici: 12
#     Esempi: [12, 2, 11, 7, 9]
#     Valori nulli: 0 (0.0%)
#
#
# NUMERICHE_CONTINUE (160 features):
# --------------------------------------------------
#   • WC_0
#     Tipo: float64 | Valori unici: 738
#     Esempi: [71.0, 94.0, 69.0]
#     Valori nulli: 2160 (0.4%)
#
#   • HC_0
#     Tipo: float64 | Valori unici: 609
#     Esempi: [87.0, 104.0, 102.0]
#     Valori nulli: 2219 (0.4%)
#
#   • Height_S_0
#     Tipo: float64 | Valori unici: 557
#     Esempi: [172.0, 174.5, 174.0]
#     Valori nulli: 2538 (0.5%)
#
#   • Height_s_0
#     Tipo: float64 | Valori unici: 443
#     Esempi: [141.0, 144.0, 135.0]
#     Valori nulli: 6276 (1.2%)
#
#   • DBP_manual_1_0
#     Tipo: float64 | Valori unici: 95
#     Esempi: [59.0, 86.0, 74.0]
#     Valori nulli: 469312 (93.4%)
#
#   • DBP_manual_2_0
#     Tipo: float64 | Valori unici: 93
#     Esempi: [84.0, 68.0, 70.0]
#     Valori nulli: 463022 (92.2%)
#
#   • Pulse_rate_manual_1_0
#     Tipo: float64 | Valori unici: 104
#     Esempi: [53.0, 61.0, 81.0]
#     Valori nulli: 469312 (93.4%)
#
#   • Pulse_rate_manual_2_0
#     Tipo: float64 | Valori unici: 99
#     Esempi: [55.0, 71.0, 77.0]
#     Valori nulli: 463022 (92.2%)
#
#   • Walks_duration_0
#     Tipo: float64 | Valori unici: 295
#     Esempi: [30.0, 120.0, 80.0]
#     Valori nulli: 24623 (4.9%)
#
#   • Duration_moderate_0
#     Tipo: float64 | Valori unici: 255
#     Esempi: [30.0, 60.0, 120.0]
#     Valori nulli: 91448 (18.2%)
#
#   • Duration_vigorous_0
#     Tipo: float64 | Valori unici: 195
#     Esempi: [60.0, 10.0, 30.0]
#     Valori nulli: 207734 (41.3%)
#
#   • Sleep_0
#     Tipo: float64 | Valori unici: 25
#     Esempi: [7.0, 8.0, 6.0]
#     Valori nulli: 887 (0.2%)
#
#   • Smoke_t_c_0
#     Tipo: float64 | Valori unici: 4
#     Esempi: [0.0, 1.0, 2.0, -3.0]
#     Valori nulli: 891 (0.2%)
#
#   • Smoke_t_p_0
#     Tipo: float64 | Valori unici: 5
#     Esempi: [4.0, 3.0, 1.0, 2.0, -3.0]
#     Valori nulli: 40122 (8.0%)
#
#   • Alcohol_i_f_0
#     Tipo: float64 | Valori unici: 7
#     Esempi: [1.0, 2.0, 3.0, 5.0, 6.0]
#     Valori nulli: 897 (0.2%)
#
#   • Weight_manual_0
#     Tipo: float64 | Valori unici: 361
#     Esempi: [58.0, 102.0, 87.0]
#     Valori nulli: 495061 (98.5%)
#
#   • Age_start_smoke_0
#     Tipo: float64 | Valori unici: 64
#     Esempi: [20.0, 16.0, 12.0]
#     Valori nulli: 463181 (92.2%)
#
#   • Immigration_year_0
#     Tipo: float64 | Valori unici: 67
#     Esempi: [2004.0, 1982.0, 1997.0]
#     Valori nulli: 457872 (91.1%)
#
#   • PR_0
#     Tipo: float64 | Valori unici: 132
#     Esempi: [59.0, 35.0, 64.0]
#     Valori nulli: 331698 (66.0%)
#
#   • PW_ri_0
#     Tipo: float64 | Valori unici: 509
#     Esempi: [85.0, 92.0, 61.0]
#     Valori nulli: 331698 (66.0%)
#
#   • PW_ptp_0
#     Tipo: float64 | Valori unici: 827
#     Esempi: [118.0, 162.0, 188.0]
#     Valori nulli: 331794 (66.0%)
#
#   • PW_pp_0
#     Tipo: float64 | Valori unici: 60
#     Esempi: [22.0, 13.0, 23.0]
#     Valori nulli: 331698 (66.0%)
#
#   • PW_pn_0
#     Tipo: float64 | Valori unici: 70
#     Esempi: [34.0, 53.0, 44.0]
#     Valori nulli: 331698 (66.0%)
#
#   • PW_sp_0
#     Tipo: float64 | Valori unici: 58
#     Esempi: [22.0, 13.0, 23.0]
#     Valori nulli: 331698 (66.0%)
#
#   • PWV_manual_0
#     Tipo: float64 | Valori unici: 128
#     Esempi: [9.72, 5.83, 3.49]
#     Valori nulli: 502251 (100.0%)
#
#   • Wbody_impedance_manual_0
#     Tipo: float64 | Valori unici: 24
#     Esempi: [589.0, 738.0, 508.0]
#     Valori nulli: 502387 (100.0%)
#
#   • Leg_right_impendance_manual_0
#     Tipo: float64 | Valori unici: 22
#     Esempi: [217.0, 276.0, 270.0]
#     Valori nulli: 502387 (100.0%)
#
#   • Leg_left_impendance_manual_0
#     Tipo: float64 | Valori unici: 22
#     Esempi: [215.0, 273.0, 179.0]
#     Valori nulli: 502387 (100.0%)
#
#   • Arm_right_impendance_manual_0
#     Tipo: float64 | Valori unici: 23
#     Esempi: [348.0, 429.0, 279.0]
#     Valori nulli: 502387 (100.0%)
#
#   • Arm_left_impendance_manual_0
#     Tipo: float64 | Valori unici: 23
#     Esempi: [339.0, 438.0, 264.0]
#     Valori nulli: 502387 (100.0%)
#
#   • Height_s_0.1
#     Tipo: float64 | Valori unici: 371
#     Esempi: [91.0, 94.0, 85.0]
#     Valori nulli: 6276 (1.2%)
#
#   • Height_s_1.1
#     Tipo: float64 | Valori unici: 265
#     Esempi: [83.0, 86.0, 85.0]
#     Valori nulli: 482099 (96.0%)
#
#   • Height_s_2.1
#     Tipo: float64 | Valori unici: 310
#     Esempi: [89.0, 95.0, 90.0]
#     Valori nulli: 454309 (90.4%)
#
#   • Height_s_3.1
#     Tipo: float64 | Valori unici: 183
#     Esempi: [90.0, 87.0, 92.0]
#     Valori nulli: 497171 (99.0%)
#
#   • Smoking_status_0
#     Tipo: float64 | Valori unici: 4
#     Esempi: [0.0, 2.0, 1.0, -3.0]
#     Valori nulli: 891 (0.2%)
#
#   • Alcohol_status_0
#     Tipo: float64 | Valori unici: 4
#     Esempi: [2.0, 0.0, 1.0, -3.0]
#     Valori nulli: 897 (0.2%)
#
#   • Pack_years_0
#     Tipo: float64 | Valori unici: 1504
#     Esempi: [8.1, 8.625, 17.625]
#     Valori nulli: 351494 (70.0%)
#
#   • Pack_years_proportion_0
#     Tipo: float64 | Valori unici: 11619
#     Esempi: [0.18, 0.200581, 0.629464]
#     Valori nulli: 351494 (70.0%)
#
#   • BMI_0
#     Tipo: float64 | Valori unici: 46966
#     Esempi: [21.5319, 28.5055, 22.3279]
#     Valori nulli: 3104 (0.6%)
#
#   • Weight_0
#     Tipo: float64 | Valori unici: 1380
#     Esempi: [63.7, 86.8, 67.6]
#     Valori nulli: 2774 (0.6%)
#
#   • Age_visit_0
#     Tipo: int64 | Valori unici: 37
#     Esempi: [65, 53, 61]
#     Valori nulli: 0 (0.0%)
#
#   • PW_AS_index_0
#     Tipo: float64 | Valori unici: 19233
#     Esempi: [14.5763, 10.6173, 8.51064]
#     Valori nulli: 332651 (66.2%)
#
#   • IPAQ_activity_group
#     Tipo: float64 | Valori unici: 3
#     Esempi: [2.0, 0.0, 1.0]
#     Valori nulli: 100106 (19.9%)
#
#   • Whole_body_fat_perc_0
#     Tipo: float64 | Valori unici: 583
#     Esempi: [13.5, 29.6, 30.7]
#     Valori nulli: 10405 (2.1%)
#
#   • Whole_body_fat_mass_0
#     Tipo: float64 | Valori unici: 855
#     Esempi: [8.6, 25.7, 20.8]
#     Valori nulli: 10970 (2.2%)
#
#   • Whole_body_fatfree_0
#     Tipo: float64 | Valori unici: 726
#     Esempi: [55.1, 61.1, 46.8]
#     Valori nulli: 10173 (2.0%)
#
#   • Whole_body_water_0
#     Tipo: float64 | Valori unici: 561
#     Esempi: [40.3, 44.7, 34.3]
#     Valori nulli: 10130 (2.0%)
#
#   • Whole_body_impedance_0
#     Tipo: float64 | Valori unici: 787
#     Esempi: [547.0, 545.0, 668.0]
#     Valori nulli: 10184 (2.0%)
#
#   • Leg_right_impedance_0
#     Tipo: float64 | Valori unici: 420
#     Esempi: [235.0, 244.0, 267.0]
#     Valori nulli: 10155 (2.0%)
#
#   • Leg_left_impedance_0
#     Tipo: float64 | Valori unici: 394
#     Esempi: [234.0, 248.0, 268.0]
#     Valori nulli: 10161 (2.0%)
#
#   • Arm_right_impedance_0
#     Tipo: float64 | Valori unici: 581
#     Esempi: [285.0, 270.0, 373.0]
#     Valori nulli: 10193 (2.0%)
#
#   • Arm_left_impedance_0
#     Tipo: float64 | Valori unici: 492
#     Esempi: [297.0, 279.0, 376.0]
#     Valori nulli: 10169 (2.0%)
#
#   • Leg_right_fat_perc_0
#     Tipo: float64 | Valori unici: 617
#     Esempi: [13.6, 27.3, 34.0]
#     Valori nulli: 10164 (2.0%)
#
#   • Leg_right_fat_mass_0
#     Tipo: float64 | Valori unici: 232
#     Esempi: [1.4, 3.7, 4.0]
#     Valori nulli: 10173 (2.0%)
#
#   • Leg_right_fatfree_0
#     Tipo: float64 | Valori unici: 188
#     Esempi: [8.7, 9.9, 7.8]
#     Valori nulli: 10185 (2.0%)
#
#   • Leg_right_predictedmass_0
#     Tipo: float64 | Valori unici: 176
#     Esempi: [8.3, 9.4, 7.4]
#     Valori nulli: 10186 (2.0%)
#
#   • Leg_left_fat_perc_0
#     Tipo: float64 | Valori unici: 597
#     Esempi: [13.8, 26.8, 34.2]
#     Valori nulli: 10196 (2.0%)
#
#   • Leg_left_fat_mass_0
#     Tipo: float64 | Valori unici: 230
#     Esempi: [1.4, 3.6, 4.0]
#     Valori nulli: 10201 (2.0%)
#
#   • Leg_left_fatfree_0
#     Tipo: float64 | Valori unici: 182
#     Esempi: [8.5, 9.9, 7.7]
#     Valori nulli: 10220 (2.0%)
#
#   • Leg_left_predictedmass_0
#     Tipo: float64 | Valori unici: 173
#     Esempi: [8.1, 9.4, 7.2]
#     Valori nulli: 10226 (2.0%)
#
#   • Arm_right_fat_perc_0
#     Tipo: float64 | Valori unici: 704
#     Esempi: [13.8, 23.1, 26.5]
#     Valori nulli: 10238 (2.0%)
#
#   • Arm_right_fat_mass_0
#     Tipo: float64 | Valori unici: 104
#     Esempi: [0.5, 1.1, 0.9]
#     Valori nulli: 10272 (2.0%)
#
#   • Arm_right_fatfree_0
#     Tipo: float64 | Valori unici: 68
#     Esempi: [2.9, 3.6, 2.4]
#     Valori nulli: 10276 (2.0%)
#
#   • Arm_right_predictedmass_0
#     Tipo: float64 | Valori unici: 63
#     Esempi: [2.8, 3.4, 2.2]
#     Valori nulli: 10284 (2.0%)
#
#   • Arm_left_fat_perc_0
#     Tipo: float64 | Valori unici: 701
#     Esempi: [13.9, 24.3, 27.1]
#     Valori nulli: 10307 (2.1%)
#
#   • Arm_left_fat_mass_0
#     Tipo: float64 | Valori unici: 124
#     Esempi: [0.5, 1.2, 0.9]
#     Valori nulli: 10349 (2.1%)
#
#   • Arm_left_fatfree_0
#     Tipo: float64 | Valori unici: 67
#     Esempi: [3.0, 3.6, 2.4]
#     Valori nulli: 10365 (2.1%)
#
#   • Arm_left_predictedmass_0
#     Tipo: float64 | Valori unici: 63
#     Esempi: [2.8, 3.4, 2.2]
#     Valori nulli: 10384 (2.1%)
#
#   • Trunk_fat_perc_0
#     Tipo: float64 | Valori unici: 650
#     Esempi: [13.3, 32.1, 29.4]
#     Valori nulli: 10427 (2.1%)
#
#   • Trunk_fat_mass_0
#     Tipo: float64 | Valori unici: 473
#     Esempi: [4.9, 16.1, 11.1]
#     Valori nulli: 10454 (2.1%)
#
#   • Trunk_fatfree_0
#     Tipo: float64 | Valori unici: 426
#     Esempi: [32.0, 34.0, 26.6]
#     Valori nulli: 10538 (2.1%)
#
#   • Trunk_predictedmass_0
#     Tipo: float64 | Valori unici: 409
#     Esempi: [30.8, 32.7, 25.4]
#     Valori nulli: 10587 (2.1%)
#
#   • WB_count_0
#     Tipo: float64 | Valori unici: 1853
#     Esempi: [6.02, 6.41, 4.9]
#     Valori nulli: 24331 (4.8%)
#
#   • RBC_0
#     Tipo: float64 | Valori unici: 3568
#     Esempi: [4.57, 5.464, 4.45]
#     Valori nulli: 24326 (4.8%)
#
#   • Hb_0
#     Tipo: float64 | Valori unici: 1187
#     Esempi: [13.83, 16.73, 14.0]
#     Valori nulli: 24326 (4.8%)
#
#   • Hct_0
#     Tipo: float64 | Valori unici: 2983
#     Esempi: [40.41, 47.79, 41.2]
#     Valori nulli: 24326 (4.8%)
#
#   • RBDW_0
#     Tipo: float64 | Valori unici: 1291
#     Esempi: [13.39, 13.06, 12.9]
#     Valori nulli: 24328 (4.8%)
#
#   • PLT_0
#     Tipo: float64 | Valori unici: 5131
#     Esempi: [197.2, 271.3, 242.0]
#     Valori nulli: 24329 (4.8%)
#
#   • Lymph_0
#     Tipo: float64 | Valori unici: 1042
#     Esempi: [1.8, 2.45, 1.6]
#     Valori nulli: 25215 (5.0%)
#
#   • Monocyte_0
#     Tipo: float64 | Valori unici: 489
#     Esempi: [0.49, 0.47, 0.3]
#     Valori nulli: 25215 (5.0%)
#
#   • Neutroph_0
#     Tipo: float64 | Valori unici: 1409
#     Esempi: [3.47, 3.29, 2.8]
#     Valori nulli: 25215 (5.0%)
#
#   • Eos_0
#     Tipo: float64 | Valori unici: 262
#     Esempi: [0.24, 0.14, 0.2]
#     Valori nulli: 25215 (5.0%)
#
#   • Basoph_0
#     Tipo: float64 | Valori unici: 160
#     Esempi: [0.02, 0.05, 0.1]
#     Valori nulli: 25215 (5.0%)
#
#   • N_RBC_0
#     Tipo: float64 | Valori unici: 114
#     Esempi: [0.0, 0.1, 0.32]
#     Valori nulli: 25226 (5.0%)
#
#   • Lymph_perc_0
#     Tipo: float64 | Valori unici: 4617
#     Esempi: [29.86, 38.23, 32.4]
#     Valori nulli: 25209 (5.0%)
#
#   • Monocyte_perc_0
#     Tipo: float64 | Valori unici: 2552
#     Esempi: [8.15, 7.37, 6.0]
#     Valori nulli: 25209 (5.0%)
#
#   • Neutroph_perc_0
#     Tipo: float64 | Valori unici: 2972
#     Esempi: [57.7, 51.4, 57.1]
#     Valori nulli: 25209 (5.0%)
#
#   • Eos_perc_0
#     Tipo: float64 | Valori unici: 1848
#     Esempi: [3.96, 2.21, 3.2]
#     Valori nulli: 25209 (5.0%)
#
#   • Basoph_perc_0
#     Tipo: float64 | Valori unici: 1025
#     Esempi: [0.33, 0.76, 1.3]
#     Valori nulli: 25209 (5.0%)
#
#   • N_RBC_perc_0
#     Tipo: float64 | Valori unici: 661
#     Esempi: [0.0, 2.4, 3.19]
#     Valori nulli: 25230 (5.0%)
#
#   • Retic_perc_0
#     Tipo: float64 | Valori unici: 4474
#     Esempi: [1.584, 1.434, 1.34]
#     Valori nulli: 32641 (6.5%)
#
#   • Retic_count_0
#     Tipo: float64 | Valori unici: 646
#     Esempi: [0.072, 0.078, 0.06]
#     Valori nulli: 32641 (6.5%)
#
#   • Urine_microalb_0
#     Tipo: float64 | Valori unici: 4202
#     Esempi: [20.1, 24.9, 8.6]
#     Valori nulli: 349540 (69.6%)
#
#   • Creat_urine_0
#     Tipo: float64 | Valori unici: 29421
#     Esempi: [4401.0, 15884.0, 5817.0]
#     Valori nulli: 18192 (3.6%)
#
#   • K_urine_0
#     Tipo: float64 | Valori unici: 1984
#     Esempi: [51.4, 103.8, 79.9]
#     Valori nulli: 19213 (3.8%)
#
#   • Na_urine_0
#     Tipo: float64 | Valori unici: 2782
#     Esempi: [34.0, 84.3, 35.3]
#     Valori nulli: 19225 (3.8%)
#
#   • Albumine_0
#     Tipo: float64 | Valori unici: 2308
#     Esempi: [41.01, 47.6, 41.41]
#     Valori nulli: 72412 (14.4%)
#
#   • ALP_0
#     Tipo: float64 | Valori unici: 2693
#     Esempi: [69.2, 69.5, 44.1]
#     Valori nulli: 32893 (6.5%)
#
#   • ALT_0
#     Tipo: float64 | Valori unici: 10263
#     Esempi: [20.58, 30.03, 15.55]
#     Valori nulli: 33094 (6.6%)
#
#   • ApoA_0
#     Tipo: float64 | Valori unici: 1819
#     Esempi: [1.612, 1.759, 1.137]
#     Valori nulli: 74977 (14.9%)
#
#   • ApoB_0
#     Tipo: float64 | Valori unici: 1597
#     Esempi: [0.803, 0.926, 0.965]
#     Valori nulli: 35287 (7.0%)
#
#   • AST_0
#     Tipo: float64 | Valori unici: 1569
#     Esempi: [31.8, 24.7, 21.3]
#     Valori nulli: 34699 (6.9%)
#
#   • Urea_0
#     Tipo: float64 | Valori unici: 1680
#     Esempi: [5.05, 5.65, 3.61]
#     Valori nulli: 33224 (6.6%)
#
#   • Calcium_0
#     Tipo: float64 | Valori unici: 1091
#     Esempi: [2.191, 2.506, 2.463]
#     Valori nulli: 72555 (14.4%)
#
#   • Chol_0
#     Tipo: float64 | Valori unici: 7843
#     Esempi: [4.752, 5.414, 6.369]
#     Valori nulli: 32906 (6.5%)
#
#   • Crea_0
#     Tipo: float64 | Valori unici: 1921
#     Esempi: [86.2, 89.9, 49.4]
#     Valori nulli: 33138 (6.6%)
#
#   • CRP_0
#     Tipo: float64 | Valori unici: 4442
#     Esempi: [1.32, 1.15, 0.21]
#     Valori nulli: 33927 (6.8%)
#
#   • CysC_0
#     Tipo: float64 | Valori unici: 2166
#     Esempi: [0.884, 1.096, 0.744]
#     Valori nulli: 32937 (6.6%)
#
#   • glucose_0
#     Tipo: float64 | Valori unici: 10870
#     Esempi: [4.953, 6.419, 4.04]
#     Valori nulli: 72920 (14.5%)
#
#   • HBA1c_0
#     Tipo: float64 | Valori unici: 1047
#     Esempi: [40.0, 27.8, 38.3]
#     Valori nulli: 35994 (7.2%)
#
#   • HDL_0
#     Tipo: float64 | Valori unici: 2877
#     Esempi: [1.569, 1.443, 0.963]
#     Valori nulli: 72616 (14.5%)
#
#   • LDL_0
#     Tipo: float64 | Valori unici: 5971
#     Esempi: [2.778, 3.142, 3.532]
#     Valori nulli: 33789 (6.7%)
#
#   • LipoA_0
#     Tipo: float64 | Valori unici: 17890
#     Esempi: [6.3, 13.2, 12.5]
#     Valori nulli: 126846 (25.2%)
#
#   • Phosphate_0
#     Tipo: float64 | Valori unici: 1350
#     Esempi: [1.212, 1.106, 1.292]
#     Valori nulli: 73236 (14.6%)
#
#   • Total_protein_0
#     Tipo: float64 | Valori unici: 3432
#     Esempi: [69.13, 81.74, 74.66]
#     Valori nulli: 72883 (14.5%)
#
#   • TG_0
#     Tipo: float64 | Valori unici: 7566
#     Esempi: [1.021, 1.623, 0.845]
#     Valori nulli: 33281 (6.6%)
#
#   • Urate_0
#     Tipo: float64 | Valori unici: 5469
#     Esempi: [322.9, 416.7, 193.2]
#     Valori nulli: 33470 (6.7%)
#
#   • Water_intake_0
#     Tipo: float64 | Valori unici: 7
#     Esempi: [1.0, 4.0, 2.0, 555.0, 3.0]
#     Valori nulli: 442330 (88.0%)
#
#   • Water_intake_4
#     Tipo: float64 | Valori unici: 7
#     Esempi: [4.0, 2.0, 1.0, 5.0, 600.0]
#     Valori nulli: 419916 (83.6%)
#
#   • Phis_act_vig_time_0
#     Tipo: float64 | Valori unici: 8
#     Esempi: [0.0, 1030.0, 10.0, 3060.0, 24.0]
#     Valori nulli: 431721 (85.9%)
#
#   • Phis_act_vig_time_4
#     Tipo: float64 | Valori unici: 8
#     Esempi: [0.0, 1030.0, 10.0, 46.0, 24.0]
#     Valori nulli: 402189 (80.1%)
#
#   • Phis_act_mod_time_0
#     Tipo: float64 | Valori unici: 8
#     Esempi: [0.0, 1030.0, 10.0, 3060.0, 12.0]
#     Valori nulli: 431721 (85.9%)
#
#   • Phis_act_mod_time_4
#     Tipo: float64 | Valori unici: 8
#     Esempi: [0.0, 1030.0, 10.0, 3060.0, 24.0]
#     Valori nulli: 402189 (80.1%)
#
#   • Phis_act_light_time_0
#     Tipo: float64 | Valori unici: 8
#     Esempi: [13.0, 35.0, 1.0, 0.0, 79.0]
#     Valori nulli: 431721 (85.9%)
#
#   • Phis_act_light_time_4
#     Tipo: float64 | Valori unici: 8
#     Esempi: [13.0, 35.0, 1.0, 0.0, 57.0]
#     Valori nulli: 402189 (80.1%)
#
#   • inline_vf_lvm
#     Tipo: float64 | Valori unici: 5087
#     Esempi: [138.5275703, 54.08801603, 44.77425687]
#     Valori nulli: 495006 (98.5%)
#
#   • inline_vf_lvmi
#     Tipo: float64 | Valori unici: 7406
#     Esempi: [70.37583738, 30.36903391, 31.96704848]
#     Valori nulli: 495006 (98.5%)
#
#   • ml4h_reg_lvm
#     Tipo: float64 | Valori unici: 7404
#     Esempi: [97.67035, 80.33256, 76.28329]
#     Valori nulli: 495006 (98.5%)
#
#   • ml4h_reg_lvmi
#     Tipo: float64 | Valori unici: 7406
#     Esempi: [49.61923936, 45.10467231, 54.46325189]
#     Valori nulli: 495006 (98.5%)
#
#   • ml4h_seg_lvm
#     Tipo: float64 | Valori unici: 4927
#     Esempi: [142.2786134, 69.9998491, 36.3535924]
#     Valori nulli: 495006 (98.5%)
#
#   • ml4h_seg_lvmi
#     Tipo: float64 | Valori unici: 7406
#     Esempi: [72.28147101, 39.30312012, 25.95502711]
#     Valori nulli: 495006 (98.5%)
#
#   • Elapsed_time_visit0_death0
#     Tipo: int64 | Valori unici: 6000
#     Esempi: [-40150, -39870, -39392]
#     Valori nulli: 0 (0.0%)
#
#   • Medicat_n_0
#     Tipo: float64 | Valori unici: 33
#     Esempi: [0.0, 5.0, 13.0]
#     Valori nulli: 862 (0.2%)
#
#   • T2D_diagnosis_0
#     Tipo: float64 | Valori unici: 4
#     Esempi: [0.0, 1.0, -1.0, -3.0]
#     Valori nulli: 931 (0.2%)
#
#   • Taking_other_prescr_medicat_0
#     Tipo: float64 | Valori unici: 4
#     Esempi: [0.0, 1.0, -1.0, -3.0]
#     Valori nulli: 931 (0.2%)
#
#   • T2D_age_diagnosis_0
#     Tipo: float64 | Valori unici: 72
#     Esempi: [52.0, 64.0, 60.0]
#     Valori nulli: 477134 (95.0%)
#
#   • Med_cbde_0_0
#     Tipo: float64 | Valori unici: 8
#     Esempi: [-7.0, 1.0, 4.0, 2.0, 5.0]
#     Valori nulli: 231613 (46.1%)
#
#   • Med_cbde_1_0
#     Tipo: float64 | Valori unici: 4
#     Esempi: [2.0, 5.0, 4.0, 3.0]
#     Valori nulli: 477818 (95.1%)
#
#   • Med_cbde_2_0
#     Tipo: float64 | Valori unici: 3
#     Esempi: [5.0, 4.0, 3.0]
#     Valori nulli: 499998 (99.5%)
#
#   • Med_cbd_0_0
#     Tipo: float64 | Valori unici: 6
#     Esempi: [-7.0, 1.0, 2.0, -1.0, -3.0]
#     Valori nulli: 275514 (54.8%)
#
#   • Age_Death
#     Tipo: float64 | Valori unici: 426
#     Esempi: [69.1, 77.2, 76.1]
#     Valori nulli: 467376 (93.0%)
#
#   • Follow_up_time
#     Tipo: int64 | Valori unici: 4286
#     Esempi: [3651, 0, 1909]
#     Valori nulli: 0 (0.0%)
#
#   • Time_to_death
#     Tipo: float64 | Valori unici: 4932
#     Esempi: [2806.0, 3773.0, 2993.0]
#     Valori nulli: 467376 (93.0%)
#
#   • SBP_manual_0
#     Tipo: float64 | Valori unici: 278
#     Esempi: [116.5, 117.0, 135.0]
#     Valori nulli: 458618 (91.3%)
#
#   • SBP_auto_0
#     Tipo: float64 | Valori unici: 339
#     Esempi: [131.5, 149.0, 149.5]
#     Valori nulli: 30114 (6.0%)
#
#   • DBP_auto_0
#     Tipo: float64 | Valori unici: 201
#     Esempi: [63.5, 88.5, 85.0]
#     Valori nulli: 30109 (6.0%)
#
#   • Pulse_rate_Auto_manual_0
#     Tipo: float64 | Valori unici: 237
#     Esempi: [59.0, 76.0, 80.0]
#     Valori nulli: 30109 (6.0%)
#
#   • Time_BP_measure_manual_0
#     Tipo: float64 | Valori unici: 2291
#     Esempi: [133.0, 137.0, 255.5]
#     Valori nulli: 862 (0.2%)
#
#   • Months_from_first_IDDM
#     Tipo: float64 | Valori unici: 634
#     Esempi: [-29.0, 18.0, 398.0]
#     Valori nulli: 497231 (99.0%)
#
#   • Months_from_first_NIDDM
#     Tipo: float64 | Valori unici: 541
#     Esempi: [-65.0, -104.0, -22.0]
#     Valori nulli: 458608 (91.3%)
#
#   • Months_from_first_malnutrition_DM
#     Tipo: float64 | Valori unici: 7
#     Esempi: [-129.0, 144.0, -124.0, -14.0, -109.0]
#     Valori nulli: 502405 (100.0%)
#
#   • Months_from_first_other_DM
#     Tipo: float64 | Valori unici: 211
#     Esempi: [-139.0, -83.0, 61.0]
#     Valori nulli: 501867 (99.9%)
#
#   • Months_from_first_unspecified_DM
#     Tipo: float64 | Valori unici: 902
#     Esempi: [162.0, 64.0, 93.0]
#     Valori nulli: 476876 (94.9%)
#
#   • Months_from_first_primary_hypertension
#     Tipo: float64 | Valori unici: 940
#     Esempi: [57.0, 12.0, 14.0]
#     Valori nulli: 307605 (61.2%)
#
#   • Months_from_first_secondary_hypertension
#     Tipo: float64 | Valori unici: 194
#     Esempi: [-102.0, 107.0, -147.0]
#     Valori nulli: 502114 (99.9%)
#
#   • Months_from_first_hypertension_pregnancy
#     Tipo: float64 | Valori unici: 111
#     Esempi: [117.0, 122.0, -59.0]
#     Valori nulli: 502282 (100.0%)
#
#   • Months_from_first_no_proteinuria_hypertension_pregnancy
#     Tipo: float64 | Valori unici: 324
#     Esempi: [-41.0, 119.0, 75.0]
#     Valori nulli: 501576 (99.8%)
#
#   • Months_from_first_yes_proteinuria_hypertension_pregnancy
#     Tipo: float64 | Valori unici: 266
#     Esempi: [40.0, 126.0, 86.0]
#     Valori nulli: 501835 (99.9%)
#
#   • Months_from_first_unspecified_hypertension_pregnancy
#     Tipo: float64 | Valori unici: 587
#     Esempi: [54.0, 86.0, 487.0]
#     Valori nulli: 499569 (99.4%)
#
#   • Months_from_first_DM_pregnancy
#     Tipo: float64 | Valori unici: 383
#     Esempi: [108.0, 9.0, 121.0]
#     Valori nulli: 501632 (99.8%)
#
#
# TESTO_LUNGO (1 features):
# --------------------------------------------------
#   • PW_time_0
#     Tipo: object | Valori unici: 170714
#     Esempi: ['100|0,0|1,107|2,414|3,975|4,1789|5,2797|6,3902|7,5001|8,6013|9,6885|10,7597|11,8151|12,8567|13,8876|14,9108|15,9285|16,9429|17,9553|18,9667|19,9773|20,9869|21,9947|22,9987|23,9970|24,9882|25,9720|26,9498|27,9249|28,9007|29,8803|30,8655|31,8563|32,8517|33,8497|34,8481|35,8453|36,8400|37,8316|38,8200|39,8057|40,7896|41,7721|42,7539|43,7350|44,7157|45,6964|46,6772|47,6586|48,6405|49,6231|50,6063|51,5901|52,5748|53,5601|54,5462|55,5330|56,5205|57,5086|58,4973|59,4861|60,4749|61,4637|62,4522|63,4402|64,4277|65,4147|66,4012|67,3874|68,3735|69,3595|70,3456|71,3317|72,3178|73,3040|74,2901|75,2763|76,2627|77,2495|78,2364|79,2234|80,2107|81,1983|82,1862|83,1743|84,1626|85,1512|86,1397|87,1279|88,1155|89,1029|90,903|91,780|92,658|93,538|94,421|95,308|96,197|97,97|98,22|99,0|', '100|0,3|1,123|2,780|3,2139|4,3928|5,5647|6,7017|7,8018|8,8725|9,9219|10,9567|11,9802|12,9941|13,9992|14,9961|15,9866|16,9738|17,9618|18,9531|19,9479|20,9452|21,9431|22,9405|23,9360|24,9301|25,9231|26,9152|27,9062|28,8963|29,8858|30,8748|31,8639|32,8532|33,8428|34,8322|35,8218|36,8114|37,8007|38,7898|39,7779|40,7652|41,7512|42,7362|43,7203|44,7036|45,6870|46,6708|47,6550|48,6403|49,6282|50,6207|51,6186|52,6206|53,6232|54,6239|55,6213|56,6158|57,6080|58,5982|59,5868|60,5737|61,5591|62,5428|63,5252|64,5075|65,4905|66,4744|67,4591|68,4448|69,4306|70,4165|71,4019|72,3872|73,3727|74,3578|75,3423|76,3262|77,3099|78,2931|79,2760|80,2590|81,2420|82,2251|83,2090|84,1936|85,1783|86,1634|87,1485|88,1342|89,1202|90,1067|91,935|92,808|93,692|94,581|95,468|96,348|97,215|98,80|99,3|', '100|0,4|1,53|2,198|3,468|4,877|5,1428|6,2102|7,2871|8,3698|9,4539|10,5356|11,6120|12,6811|13,7421|14,7951|15,8404|16,8789|17,9112|18,9378|19,9594|20,9763|21,9887|22,9966|23,9998|24,9980|25,9909|26,9776|27,9582|28,9332|29,9039|30,8720|31,8393|32,8073|33,7774|34,7505|35,7271|36,7071|37,6901|38,6758|39,6634|40,6520|41,6414|42,6309|43,6199|44,6082|45,5958|46,5826|47,5689|48,5548|49,5402|50,5252|51,5098|52,4939|53,4779|54,4619|55,4459|56,4302|57,4147|58,3996|59,3846|60,3697|61,3550|62,3407|63,3267|64,3132|65,2999|66,2871|67,2746|68,2624|69,2504|70,2387|71,2273|72,2161|73,2051|74,1944|75,1837|76,1733|77,1632|78,1534|79,1441|80,1353|81,1270|82,1191|83,1116|84,1043|85,970|86,896|87,821|88,742|89,662|90,582|91,502|92,423|93,346|94,270|95,196|96,127|97,68|98,22|99,4|']
#     Valori nulli: 331698 (66.0%)
#
#
# ALTRO (3 features):
# --------------------------------------------------
#   • Urine_microalb_flag_0
#     Tipo: COSTANTE | Valori unici: 1
#     Esempi: [1.0]
#     Valori nulli: 171084 (34.1%)
#
#   • Creat_urine_flag_0
#     Tipo: COSTANTE | Valori unici: 1
#     Esempi: ['<88']
#     Valori nulli: 502408 (100.0%)
#
#   • Med_cbd_2_0
#     Tipo: COSTANTE | Valori unici: 1
#     Esempi: [3.0]
#     Valori nulli: 500491 (99.6%)
#
#
# ============================================================
# SOMMARIO CLASSIFICAZIONE
# ============================================================
# BINARIE............................ 137 ( 44.8%)
# CATEGORICHE_ALTA_CARDINALITA.......   4 (  1.3%)
# NUMERICHE_DISCRETE.................   1 (  0.3%)
# NUMERICHE_CONTINUE................. 160 ( 52.3%)
# TESTO_LUNGO........................   1 (  0.3%)
# ALTRO..............................   3 (  1.0%)
#
#
# CORRELAZIONI TRA VARIABILI BINARIE (137 variabili):
# ------------------------------------------------------------
# Errore durante l'analisi: could not convert string to float: '>200'
#
#
# VARIABILI GENETICHE IDENTIFICATE (63):
# --------------------------------------------------
# rs2820037__0_0: {0: 501649, 1: 763}
# rs2820037__A_A: {1: 344477, 0: 157935}
# rs2820037__T_A: {0: 372475, 1: 129937}
# rs2820037__T_T: {0: 489415, 1: 12997}
# rs1805762__0_0: {0: 501262, 1: 1150}
# rs1805762__C_C: {1: 435681, 0: 66731}
# rs1805762__G_C: {0: 452642, 1: 49770}
# rs1805762__G_G: {0: 500839, 1: 1573}
# rs1126742__0_0: {0: 501004, 1: 1408}
# rs1126742__A_A: {1: 355934, 0: 146478}
#
#
# VARIABILI TEMPORALI IDENTIFICATE (36):
# --------------------------------------------------
# Vdate_0: range 2006-03-13 - 2010-10-01
# Vmonth_0: range 1 - 12
# Walks_duration_0: range -3.0 - 1440.0
# Duration_moderate_0: range -3.0 - 1440.0
# Duration_vigorous_0: range -3.0 - 1440.0
# Age_start_smoke_0: range -3.0 - 69.0
# Immigration_year_0: range -3.0 - 2009.0

# %%
# Top 20 per % missing
missing = (df.isnull().mean()*100).sort_values(ascending=False).head(50)
print("\nTOP 20 COLONNE PER MISSING (%):")
print(missing.to_string())
# Out:
# TOP 20 COLONNE PER MISSING (%):
# Creat_urine_flag_0                                          99.999204
# Months_from_first_malnutrition_DM                           99.998607
# Wbody_impedance_manual_0                                    99.995024
# Arm_left_impendance_manual_0                                99.995024
# Leg_right_impendance_manual_0                               99.995024
# Leg_left_impendance_manual_0                                99.995024
# Arm_right_impendance_manual_0                               99.995024
# Med_cbde_3_0                                                99.981489
# Months_from_first_hypertension_pregnancy                    99.974125
# PWV_manual_0                                                99.967955
# Months_from_first_secondary_hypertension                    99.940686
# Months_from_first_other_DM                                  99.891523
# Months_from_first_yes_proteinuria_hypertension_pregnancy    99.885154
# Months_from_first_DM_pregnancy                              99.844749
# Months_from_first_no_proteinuria_hypertension_pregnancy     99.833603
# K_urine_flag_0                                              99.797178
# Na_urine_flag_0                                             99.795188
# Lost_FU                                                     99.741646
# Med_cbd_2_0                                                 99.617644
# Med_cbde_2_0                                                99.519518
# Quality_IMT_120                                             99.486875
# Quality_IMT_150                                             99.486875
# Quality_IMT_210                                             99.486875
# Quality_IMT_240                                             99.486875
# Months_from_first_unspecified_hypertension_pregnancy        99.434130
# Months_from_first_IDDM                                      98.968775
# Height_s_3.1                                                98.956832
# Weight_manual_0                                             98.536858
# ml4h_seg_lvmi                                               98.525911
# ml4h_seg_lvm                                                98.525911
# ml4h_reg_lvmi                                               98.525911
# ml4h_reg_lvm                                                98.525911
# inline_vf_lvmi                                              98.525911
# inline_vf_lvm                                               98.525911
# Height_s_1.1                                                95.956904
# Med_cbde_1_0                                                95.104814
# T2D_age_diagnosis_0                                         94.968671
# Months_from_first_unspecified_DM                            94.917319
# Pulse_rate_manual_1_0                                       93.411782
# DBP_manual_1_0                                              93.411782
# Med_cbd_1_0                                                 93.148651
# Cause_of_death                                              93.050524
# Time_to_death                                               93.026440
# Death_date                                                  93.026440
# Age_Death                                                   93.026440
# Age_start_smoke_0                                           92.191468
# DBP_manual_2_0                                              92.159821
# Pulse_rate_manual_2_0                                       92.159821
# SBP_manual_0                                                91.283250
# Months_from_first_NIDDM                                     91.281259
